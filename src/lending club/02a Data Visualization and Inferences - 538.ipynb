# %% [markdown]
# <br><br>
# <h1 align="center"> 02 Data Visualization and Inferences - 538 </h1>
# <br><br>

# %%
'''Import the libraries'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot
from IPython.display import HTML
from mpl_toolkits.mplot3d import Axes3D
import hashlib
import joblib
import datetime
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit

# %%
'''Load the data. It's big, set low_memory=False'''
loan_data = pd.read_csv('/opt/apps/ml-data/bigdata/lending_club/loan_data.csv', low_memory=False)

# %%
'''Update the datetime columns from String to datetime'''
loan_data['issue_d'] = pd.to_datetime(loan_data['issue_d'])
loan_data['earliest_cr_line'] = pd.to_datetime(loan_data['earliest_cr_line'])

# %%
loan_data['addr_state'].unique()

'''Make a list with each of the regions by state.'''
west = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
south_west = ['AZ', 'TX', 'NM', 'OK']
south_east = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
mid_west = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
north_east = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']


loan_data['Region'] = np.nan

def finding_regions(state):
    if state in west:
        return 'West'
    elif state in south_west:
        return 'South West'
    elif state in south_east:
        return 'South East'
    elif state in mid_west:
        return 'Mid West'
    elif state in north_east:
        return 'North East'


loan_data['Region'] = loan_data['addr_state'].apply(finding_regions)
loan_data['Region'].value_counts()
# Out:
# South East    323587
# West          318529
# North East    301767
# Mid West      232678
# South West    161663
# Name: Region, dtype: int64

# %%
'''Pie and Bar comparison of the loan status'''
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(15, 10))
plt.style.use('fivethirtyeight') 


plt.subplot(1, 2, 1)
risk_counts = loan_data['Risk'].value_counts()
risk_counts.plot.pie(autopct='%1.2f%%')

plt.title('Loan Risk Distribution (part - whole)', alpha = 0.75)
plt.xlabel('')
plt.ylabel('% of Loan Condition', alpha = 0.75)


plt.subplot(1, 2, 2)
g = sns.barplot(x=loan_data['issue_d'].dt.year, y="loan_amnt", 
            hue="Risk", data=loan_data, 
            estimator=lambda x: len(x) / len(loan_data) * 100)
plt.title('Loan Risk Distribution per Year', alpha = 0.75)
plt.xlabel('Year', alpha = 0.75)
plt.ylabel('% of Loan Risk', alpha = 0.75)
plt.xticks(rotation=90)


l = g.legend()
l.texts[0].set_text("No Risk")
l.texts[1].set_text("Risk")
plt.savefig('plots/1.png')
plt.show()

# %%
'''What defines good or bad loan? Show the count plot of loan status count.'''
fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(15, 10))
plt.style.use('fivethirtyeight')

loan_data['loan_status'].value_counts().plot.bar()

total = float(len(loan_data['loan_status']))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height+15000,
            '{:1.3f}%'.format((height/total)*100),
            ha="center", alpha=0.75) 

plt.title('Loan Status Distribution', alpha=0.75)
plt.ylabel('Count', alpha=0.75)
plt.xlabel('')
plt.xticks(rotation=60)

plt.savefig('plots/2.png', bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(15, 10))
plt.style.use('fivethirtyeight')


plt.subplot(1, 2, 1)
risk_counts = loan_data['Risk'].value_counts()
risk_counts.plot.pie(autopct='%1.2f%%')

plt.title('Loan Risk Distribution (part - whole)', alpha=0.75)
plt.xlabel('')
plt.ylabel('% of Loan Condition', alpha=0.75)


plt.subplot(1, 2, 2)
bad_loan = loan_data[loan_data['loan_status'] != 'Fully Paid']
bad_counts = bad_loan['loan_status'].value_counts()
plot = bad_counts.plot.bar()
total = float(len(bad_loan['loan_status']))

for p in plot.patches:
    height = p.get_height()
    plot.text(p.get_x()+p.get_width()/2.,
            height+5000,
            '{:1.2f}%'.format((height/total)*100),
            ha="center", alpha=0.75) 

plt.title('Risk Types Distribution', alpha=0.75)
plt.ylabel('Count', alpha=0.75)
plt.xlabel('')
plt.xticks(rotation=30)

plt.savefig('plots/3.png', bbox_inches="tight")
plt.show()

# %%
colors = [[0,0,0], [230/255,159/255,0], [86/255,180/255,233/255], [0,158/255,115/255],
          [213/255,94/255,0], [0,114/255,178/255]]

fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(15, 10))
plt.style.use('fivethirtyeight')

sns.lineplot(x=loan_data['issue_d'].dt.year, y='loan_amnt', 
             hue='loan_status', data=loan_data, ci=None, legend=False)

plt.text(x=2007, y=21000, s='Note: some Categories were introduced in the year 2013 and 2016', 
         fontsize=16, alpha=0.85)

plt.text(x=2010, y=11500, s='Charged Off', color = colors[0], weight='bold', rotation=50,
              backgroundcolor='#f0f0f0')
plt.text(x=2010.3, y=10500, s='Fully Paid', color = colors[5], weight='bold', rotation=35,
              backgroundcolor='#f0f0f0')
plt.text(x=2012.5, y=16500,s ='Late (31-120 days)', color = colors[4], weight='bold', rotation=50,
              backgroundcolor='#f0f0f0')
plt.text(x=2013.7, y=16000, s='Late (16-30 days)', color = colors[3], weight='bold', rotation=73,
              backgroundcolor='#f0f0f0')
plt.text(x=2013.1, y=11300, s='In Grace Period', color = colors[1], weight='bold', rotation=78,
              backgroundcolor='#f0f0f0')
plt.text(x=2016.2, y=12000, s='Default', color = colors[2], weight='bold', rotation=60,
              backgroundcolor='#f0f0f0')

plt.title('How the average loan amount changed over time (per status)', alpha=0.75)
plt.xlabel('Year', alpha=0.75)
plt.ylabel('Average Loan Amount in dollars', alpha=0.75)

plt.savefig('plots/4.png')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, sharex=True, sharey=True, figsize=(15, 10))
plt.style.use('fivethirtyeight')

sns.lineplot(x=loan_data['issue_d'].dt.year, y="loan_amnt", hue="Region", data=loan_data, ci=None)

plt.title('Region wise Loan Distribution', alpha=0.75)
plt.xlabel('Year', alpha=0.75)
plt.ylabel('Average Loan Amount (in dollars)', alpha=0.75)

ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, loc='lower right')

plt.savefig('plots/5.png')
plt.show()

# %%
'''Data preparation for map'''
by_loan_amount = loan_data.groupby(['Region','addr_state'], as_index=False).loan_amnt.sum()
by_interest_rate = loan_data.groupby(['Region', 'addr_state'], as_index=False).int_rate.mean()
by_income = loan_data.groupby(['Region', 'addr_state'], as_index=False).annual_inc.mean()

'''Take the values to a list for visualization purposes.'''
states = by_loan_amount['addr_state'].values.tolist()
average_loan_amounts = by_loan_amount['loan_amnt'].values.tolist()
average_interest_rates = by_interest_rate['int_rate'].values.tolist()
average_annual_income = by_income['annual_inc'].values.tolist()


from collections import OrderedDict

metrics_data = OrderedDict([('state_codes', states),
                            ('issued_loans', average_loan_amounts),
                            ('interest_rate', average_interest_rates),
                            ('annual_income', average_annual_income)])
                     

metrics_df = pd.DataFrame.from_dict(metrics_data)
metrics_df = metrics_df.round(decimals=2)
metrics_df.head()
# Out:
#   state_codes  issued_loans  interest_rate  annual_income
# 0          IA         70375          10.87       47570.86
# 1          IL     756318450          13.14       77966.43
# 2          IN     303676075          13.47       69004.47
# 3          KS     156932250          13.20       69805.09
# 4          MI     485185900          13.42       70059.69

# %%
'''Now it comes the part where we plot out plotly United States map'''
for col in metrics_df.columns:
    metrics_df[col] = metrics_df[col].astype(str)
    
scl = [[0.0, 'rgb(210, 241, 198)'],[0.2, 'rgb(188, 236, 169)'],[0.4, 'rgb(171, 235, 145)'],\
            [0.6, 'rgb(140, 227, 105)'],[0.8, 'rgb(105, 201, 67)'],[1.0, 'rgb(59, 159, 19)']]

colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"
]

metrics_df['text'] = metrics_df['state_codes'] + '<br>' +\
'Average loan interest rate: ' + metrics_df['interest_rate'] + '<br>'+\
'Average annual income: ' + metrics_df['annual_income'] 


data = [ dict(
        type='choropleth',
        colorscale
<br>Average loan interest rate: 13.44<br>Average annual income: 74777.16", "MS<br>Average loan interest rate: 13.67<br>Average annual income: 68789.59", "NC<br>Average loan interest rate: 13.47<br>Average annual income: 72270.77", "SC<br>Average loan interest rate: 13.44<br>Average annual income: 72596.73", "TN<br>Average loan interest rate: 13.58<br>Average annual income: 69010.31", "VA<br>Average loan interest rate: 13.34<br>Average annual income: 82368.8", "WV<br>Average loan interest rate: 13.22<br>Average annual income: 67227.02", "AZ<br>Average loan interest rate: 13.16<br>Average annual income: 72766.32", "NM<br>Average loan interest rate: 13.34<br>Average annual income: 70909.97", "OK<br>Average loan interest rate: 13.5<br>Average annual income: 70623.71", "TX<br>Average loan interest rate: 13.23<br>Average annual income: 81328.95", "AK<br> ...
#                         {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "height": 700, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"

# %%
'''Now it comes the part where we plot out plotly United States map'''
for col in metrics_df.columns:
    metrics_df[col] = metrics_df[col].astype(str)
    
scl = [[0.0, 'rgb(210, 241, 198)'],[0.2, 'rgb(188, 236, 169)'],[0.4, 'rgb(171, 235, 145)'],\
            [0.6, 'rgb(140, 227, 105)'],[0.8, 'rgb(105, 201, 67)'],[1.0, 'rgb(59, 159, 19)']]

colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"
]

metrics_df['text'] = metrics_df['state_codes'] + '<br>' +\
'Average loan interest rate: ' + metrics_df['interest_rate'] + '<br>'+\
'Average annual income: ' + metrics_df['annual_income'] 


data = [ dict(
        type='choropleth',
        colorscale = colorscale,
        autocolorscale = False,
        locations = metrics_df['state_codes'],
        z = metrics_df['interest_rate'], 
        locationmode = 'USA-states',
        text = metrics_df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Interest Rate (%)")
        ) ]


layout = dict(
    title = '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Interest Rate (%) Distribution in different states of USA',
    width=925,
    height=700,
    geo = dict(
        scope = 'usa',
        projection=dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)')
    )

fig = dict(data=data, layout=layout)
iplot(fig, filename='d3-cloropleth-map')
# plt.savefig('plots/6.png')
# Out:
# <div>
#
#
#             <div id="8e64a8dd-1854-4bbd-ba84-8e1b4616df87" class="plotly-graph-div" style="height:700px; width:925px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e64a8dd-1854-4bbd-ba84-8e1b4616df87")) {
#                     Plotly.newPlot(
#                         '8e64a8dd-1854-4bbd-ba84-8e1b4616df87',
#                         [{"autocolorscale": false, "colorbar": {"title": {"text": "Interest Rate (%)"}}, "colorscale": [[0.0, "#f7fbff"], [0.0625, "#ebf3fb"], [0.125, "#deebf7"], [0.1875, "#d2e3f3"], [0.25, "#c6dbef"], [0.3125, "#b3d2e9"], [0.375, "#9ecae1"], [0.4375, "#85bcdb"], [0.5, "#6baed6"], [0.5625, "#57a0ce"], [0.625, "#4292c6"], [0.6875, "#3082be"], [0.75, "#2171b5"], [0.8125, "#1361a9"], [0.875, "#08519c"], [0.9375, "#0b4083"], [1.0, "#08306b"]], "locationmode": "USA-states", "locations": ["IA", "IL", "IN", "KS", "MI", "MN", "MO", "ND", "NE", "OH", "SD", "WI", "CT", "MA", "MD", "ME", "NH", "NJ", "NY", "PA", "RI", "VT", "AL", "AR", "DC", "DE", "FL", "GA", "KY", "LA", "MS", "NC", "SC", "TN", "VA", "WV", "AZ", "NM", "OK", "TX", "AK", "CA", "CO", "HI", "ID", "MT", "NV", "OR", "UT", "WA", "WY"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "text": ["IA<br>Average loan interest rate: 10.87<br>Average annual income: 47570.86", "IL<br>Average loan interest rate: 13.14<br>Average annual income: 77966.43", "IN<br>Average loan interest rate: 13.47<br>Average annual income: 69004.47", "KS<br>Average loan interest rate: 13.2<br>Average annual income: 69805.09", "MI<br>Average loan interest rate: 13.42<br>Average annual income: 70059.69", "MN<br>Average loan interest rate: 13.19<br>Average annual income: 71296.44", "MO<br>Average loan interest rate: 13.3<br>Average annual income: 68617.33", "ND<br>Average loan interest rate: 13.68<br>Average annual income: 75830.11", "NE<br>Average loan interest rate: 13.61<br>Average annual income: 64418.09", "OH<br>Average loan interest rate: 13.33<br>Average annual income: 67581.87", "SD<br>Average loan interest rate: 13.45<br>Average annual income: 61978.5", "WI<br>Average loan interest rate: 13.07<br>Average annual income: 67272.5", "CT<br>Average loan interest rate: 13.21<br>Average annual income: 84689.86", "MA<br>Average loan interest rate: 12.85<br>Average annual income: 81284.07", "MD<br>Average loan interest rate: 13.46<br>Average annual income: 84279.62", "ME<br>Average loan interest rate: 12.98<br>Average annual income: 67613.71", "NH<br>Average loan interest rate: 12.94<br>Average annual income: 77451.76", "NJ<br>Average loan interest rate: 13.22<br>Average annual income: 86276.45", "NY<br>Average loan interest rate: 13.46<br>Average annual income: 79325.23", "PA<br>Average loan interest rate: 13.4<br>Average annual income: 71821.65", "RI<br>Average loan interest rate: 13.2<br>Average annual income: 72446.65", "VT<br>Average loan interest rate: 12.96<br>Average annual income: 65399.03", "AL<br>Average loan interest rate: 13.81<br>Average annual income: 68884.82", "AR<br>Average loan interest rate: 13.59<br>Average annual income: 66420.39", "DC<br>Average loan interest rate: 12.68<br>Average annual income: 91251.0", "DE<br>Average loan interest rate: 13.45<br>Average annual income: 75241.15", "FL<br>Average loan interest rate: 13.4<br>Average annual income: 71366.45", "GA<br>Average loan interest rate: 13.38<br>Average annual income: 76041.24", "KY<br>Average loan interest rate: 13.4<br>Average annual income: 67575.11", "LA<br>Average loan interest rate: 13.44<br>Average annual income: 74777.16", "MS<br>Average loan interest rate: 13.67<br>Average annual income: 68789.59", "NC<br>Average loan interest rate: 13.47<br>Average annual income: 72270.77", "SC<br>Average loan interest rate: 13.44<br>Average annual income: 72596.73", "TN<br>Average loan interest rate: 13.58<br>Average annual income: 69010.31", "VA<br>Average loan interest rate: 13.34<br>Average annual income: 82368.8", "WV<br>Average loan interest rate: 13.22<br>Average annual income: 67227.02", "AZ<br>Average loan interest rate: 13.16<br>Average annual income: 72766.32", "NM<br>Average loan interest rate: 13.34<br>Average annual income: 70909.97", "OK<br>Average loan interest rate: 13.5<br>Average annual income: 70623.71", "TX<br>Average loan interest rate: 13.23<br>Average annual income: 81328.95", "AK<br> ...
#                         {"geo": {"lakecolor": "rgb(255, 255, 255)", "projection": {"type": "albers usa"}, "scope": "usa", "showlakes": true}, "height": 700, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth"

# %%
'''Now it comes the part where we plot out plotly United States map'''
for col in metrics_df.columns:
    metrics_df[col] = metrics_df[col].astype(str)
    
scl = [[0.0, 'rgb(210, 241, 198)'],[0.2, 'rgb(188, 236, 169)'],[0.4, 'rgb(171, 235, 145)'],\
            [0.6, 'rgb(140, 227, 105)'],[0.8, 'rgb(105, 201, 67)'],[1.0, 'rgb(59, 159, 19)']]

colorscale = ["#f7fbff", "#ebf3fb", "#deebf7", "#d2e3f3", "#c6dbef", "#b3d2e9", "#9ecae1",
    "#85bcdb", "#6baed6", "#57a0ce", "#4292c6", "#3082be", "#2171b5", "#1361a9",
    "#08519c", "#0b4083", "#08306b"
]

metrics_df['text'] = metrics_df['state_codes'] + '<br>' +\
'Average loan interest rate: ' + metrics_df['interest_rate'] + '<br>'+\
'Average annual income: ' + metrics_df['annual_income'] 


data = [ dict(
        type='choropleth',
        colorscale = colorscale,
        autocolorscale = False,
        locations = metrics_df['state_codes'],
        z = metrics_df['annual_income'], 
        locationmode = 'USA-states',
        text = metrics_df['text'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Annual Income (in dollars)")
        ) ]


layout = dict(
    title = '&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Annual Income Distribution in different states of USA',
    width=925,
    height=700,
    geo = dict(
        scope = 'usa',
        projection=dict(type='albers usa'),
        showlakes = True,
        lakecolor = 'rgb(255, 255, 255)')
    )

fig = dict(data=data, layout=layout)
iplot(fig, filename='d3-cloropleth-map')
# plt.savefig('plots/7.png')
# Out:
# <div>
#
#
#             <div id="8e0e3bf5-0fcc-48eb-a6c2-35b5204ef57e" class="plotly-graph-div" style="height:700px; width:925px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8e0e3bf5-0fcc-48eb-a6c2-35b5204ef57e")) {
#                     Plotly.newPlot(
#                         '8e0e3bf5-0fcc-48eb-a6c2-35b5204ef57e',
#                         [{"autocolorscale": false, "colorbar": {"title": {"text": "Annual Income (in dollars)"}}, "colorscale": [[0.0, "#f7fbff"], [0.0625, "#ebf3fb"], [0.125, "#deebf7"], [0.1875, "#d2e3f3"], [0.25, "#c6dbef"], [0.3125, "#b3d2e9"], [0.375, "#9ecae1"], [0.4375, "#85bcdb"], [0.5, "#6baed6"], [0.5625, "#57a0ce"], [0.625, "#4292c6"], [0.6875, "#3082be"], [0.75, "#2171b5"], [0.8125, "#1361a9"], [0.875, "#08519c"], [0.9375, "#0b4083"], [1.0, "#08306b"]], "locationmode": "USA-states", "locations": ["IA", "IL", "IN", "KS", "MI", "MN", "MO", "ND", "NE", "OH", "SD", "WI", "CT", "MA", "MD", "ME", "NH", "NJ", "NY", "PA", "RI", "VT", "AL", "AR", "DC", "DE", "FL", "GA", "KY", "LA", "MS", "NC", "SC", "TN", "VA", "WV", "AZ", "NM", "OK", "TX", "AK", "CA", "CO", "HI", "ID", "MT", "NV", "OR", "UT", "WA", "WY"], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "text": ["IA<br>Average loan interest rate:
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper left').texts[0].set_text("Loan Status")

#plt.savefig('plots/26.png', bbox_inches="tight")
plt.show()

# %%
df_plot = loan_data.groupby(['loan_status', 'grade']).size().reset_index().pivot(
    columns='loan_status', index='grade', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Loans by Credit Grade', alpha = 0.75)
plt.xlabel('Credit Grade', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/36.png', bbox_inches="tight")
plt.show()

# %%
bad_loan = loan_data[loan_data['loan_status'] != 'Fully Paid']
df_plot = bad_loan.groupby(['loan_status', 'grade']).size().reset_index().pivot(
    columns='loan_status', index='grade', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Risk Loans by Credit Grade', alpha = 0.75)
plt.xlabel('Credit Grade', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/37.png', bbox_inches="tight")
plt.show()

# %%
df_plot = loan_data.groupby(['loan_status', 'sub_grade']).size().reset_index().pivot(
    columns='loan_status', index='sub_grade', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Loans by Credit Sub-Grade', alpha = 0.75)
plt.xlabel('Credit Sub-Grade', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/38.png', bbox_inches="tight")
plt.show()

# %%
df_plot = bad_loan.groupby(['loan_status', 'sub_grade']).size().reset_index().pivot(
    columns='loan_status', index='sub_grade', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Risk Loans by Credit Sub-Grade', alpha = 0.75)
plt.xlabel('Credit Sub-Grade', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/39.png', bbox_inches="tight")
plt.show()

# %%
df_plot = loan_data.groupby(['loan_status', 'emp_length']).size().reset_index().pivot(
    columns='loan_status', index='emp_length', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Loans by Employment Length', alpha = 0.75)
plt.xlabel('Employment Length', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/40.png', bbox_inches="tight")
plt.show()

# %%
df_plot = bad_loan.groupby(['loan_status', 'emp_length']).size().reset_index().pivot(
    columns='loan_status', index='emp_length', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Risk Loans by Employment Length', alpha = 0.75)
plt.xlabel('Employment Length', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/41.png', bbox_inches="tight")
plt.show()

# %%
df_plot = loan_data.groupby(['loan_status', 'purpose']).size().reset_index().pivot(
    columns='loan_status', index='purpose', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Loans by Loan Purpose', alpha = 0.75)
plt.xlabel('Loan Purpose', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/42.png', bbox_inches="tight")
plt.show()

# %%
df_plot = bad_loan.groupby(['loan_status', 'purpose']).size().reset_index().pivot(
    columns='loan_status', index='purpose', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Risk Loans by Loan Purpose', alpha = 0.75)
plt.xlabel('Loan Purpose', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='upper right')

plt.savefig('plots/43.png', bbox_inches="tight")
plt.show()

# %%
df_plot = loan_data.groupby(['loan_status', 'home_ownership']).size().reset_index().pivot(
    columns='loan_status', index='home_ownership', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Loans by Home Ownership', alpha = 0.75)
plt.xlabel('Home Ownership', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='center')

plt.savefig('plots/44.png', bbox_inches="tight")
plt.show()

# %%
df_plot = bad_loan.groupby(['loan_status', 'home_ownership']).size().reset_index().pivot(
    columns='loan_status', index='home_ownership', values=0)

df_plot.plot(kind='bar', stacked=True, figsize=(15,10))
plt.title('Types of Risk Loans by Home Ownership', alpha = 0.75)
plt.xlabel('Home Ownership', alpha = 0.75)
plt.ylabel('Count', alpha = 0.75)

plt.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1, 
          loc='center')

plt.savefig('plots/45.png', bbox_inches="tight")
plt.show()
